# %%
from fredapi import Fred
import matplotlib.pyplot as plt

# %%
fred = Fred('fdb0806d47250b6e310b1ce9d3baed42')

# %%
data = fred.get_series('T10Y2Y')
sp5 =  fred.get_series('SP500')

# %%
sp5 = sp5.pct_change(2) * 100

# %%
plt.plot(data)
plt.plot(sp5)

# %%
data
# Out:
# 1976-06-01    0.68
# 1976-06-02    0.71
# 1976-06-03    0.70
# 1976-06-04    0.77
# 1976-06-07    0.79
#               ...
# 2023-11-27   -0.45
# 2023-11-28   -0.39
# 2023-11-29   -0.37
# 2023-11-30   -0.36
# 2023-12-01   -0.34
# Length: 12394, dtype: float64
